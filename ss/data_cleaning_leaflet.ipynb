# %%
from pathlib import Path
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
# Loading the CSV files from the "resource" folder

# Defining the file paths
crashes_file = Path("resources/Cleaned_Fatal_Crash_Data.csv")
fatalities_file = Path("resources/Cleaned_Fatalities_Data.csv")

# Reading the CSV files into Pandas DataFrames
crashes_data = pd.read_csv(crashes_file)
fatalities_data = pd.read_csv(fatalities_file)

# %%
# Columns to keep
crashes_columns = ['Crash ID','State','Month','Year','Dayweek','Time','Crash Type','Number of Fatalities','Speed Limit','National Remoteness Areas','SA4 Name 2021','National LGA Name 2021','National Road Type','Christmas Period','Easter Period','Day of week','Time of Day']
fatalities_columns = ['Crash ID','Road User','Gender','Age','Age Group',]

# %%
# merging the CSVs
merged_data = pd.merge(crashes_data[crashes_columns], fatalities_data[fatalities_columns], on='Crash ID', how='inner')

# %%
# Cleaning data
merged_data['National Road Type'] = merged_data['National Road Type'].str.title()
merged_data['State'] = merged_data['State'].str.upper()

# %%
# Displaying the result df
merged_data
# Out:
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0      20235016    WA      9  2023  Wednesday  17:10     Single
# 1      20235016    WA      9  2023  Wednesday  17:10     Single
# 2      20235016    WA      9  2023  Wednesday  17:10     Single
# 3      20231205   NSW      9  2023   Saturday   0:01     Single
# 4      20233054   QLD      9  2023   Saturday  23:00     Single
# ...         ...   ...    ...   ...        ...    ...        ...
# 55259  19892548   VIC      1  1989     Sunday   1:00   Multiple
# 55260  19891122   NSW      1  1989    Tuesday  14:10   Multiple
# 55261  19894151    SA      1  1989  Wednesday  11:45   Multiple
# 55262  19892576   VIC      1  1989     Friday  17:15   Multiple
# 55263  19893326   QLD      1  1989     Monday   9:00   Multiple
#
#        Number of Fatalities  Speed Limit  National Remoteness Areas  ...  \
# 0                         3           70               Undetermined  ...
# 1                         3           70               Undetermined  ...
# 2                         3           70               Undetermined  ...
# 3                         1          100   Outer Regional Australia  ...
# 4                         1           80  Major Cities of Australia  ...
# ...                     ...          ...                        ...  ...
# 55259                     1           60               Undetermined  ...
# 55260                     1           60               Undetermined  ...
# 55261                     1           60               Undetermined  ...
# 55262                     1           60               Undetermined  ...
# 55263                     1           60               Undetermined  ...
#
#       National LGA Name 2021 National Road Type Christmas Period  \
# 0               Undetermined       Undetermined               No
# 1               Undetermined       Undetermined               No
# 2               Undetermined       Undetermined               No
# 3               Murray River      Arterial Road               No
# 4                 Gold Coast  Sub-Arterial Road               No
# ...                      ...                ...              ...
# 55259           Undetermined       Undetermined               No
# 55260           Undetermined       Undetermined               No
# 55261           Undetermined       Undetermined               No
# 55262           Undetermined       Undetermined               No
# 55263           Undetermined       Undetermined               No
#
#       Easter Period Day of week Time of Day   Road User  Gender Age  Age Group
# 0                No     Weekday         Day   Passenger    Male  24   17_to_25
# 1                No     Weekday         Day      Driver    Male  24   17_to_25
# 2                No     Weekday         Day   Passenger    Male  21   17_to_25
# 3                No     Weekend       Night      Driver    Male  20   17_to_25
# 4                No     Weekend       Night      Driver    Male  25   17_to_25
# ...             ...         ...         ...         ...     ...  ..        ...
# 55259            No     Weekend       Night  Pedestrian    Male  23   17_to_25
# 55260            No     Weekday         Day  Pedestrian    Male  71   65_to_74
# 55261            No     Weekday         Day  Pedestrian    Male  73   65_to_74
# 55262            No     Weekday         Day  Pedestrian  Female   6    0_to_16
# 55263            No     Weekday         Day  Pedestrian  Female   2    0_to_16
#
# [55264 rows x 21 columns]

# %%
print(merged_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55264 entries, 0 to 55263
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Crash ID                   55264 non-null  int64
#  1   State                      55264 non-null  object
#  2   Month                      55264 non-null  int64
#  3   Year                       55264 non-null  int64
#  4   Dayweek                    55264 non-null  object
#  5   Time                       55264 non-null  object
#  6   Crash Type                 55264 non-null  object
#  7   Number of Fatalities       55264 non-null  int64
#  8   Speed Limit                55264 non-null  int64
#  9   National Remoteness Areas  55264 non-null  object
#  10  SA4 Name 2021              55264 non-null  object
#  11  National LGA Name 2021     55264 non-null  object
#  12  National Road Type         55264 non-null  object
#  13  Christmas Period           55264 non-null  object
#  14  Easter Period              55264 non-null  object
#  15  Day of week                55264 non-null  object
#  16  Time of Day                55264 non-null  object
#  17  Road User                  55264 non-null  object
#  18  Gender                     55264 non-null  object
#  19  Age                        55264 non-null  int64
#  20  Age Group                  55264 non-null  object
# dtypes: int64(6), object(15)
# memory usage: 9.3+ MB
# None

# %%
# Specifying the output folder 
output_folder = "output_folder/Leaflet_Output"

# Creating the output folder 
import os
os.makedirs(output_folder, exist_ok=True)

# Defining the file path for the CSV
output_csv_file = os.path.join(output_folder, "final_merged_csv.csv")

# Saving the DataFrame as a CSV file
merged_data.to_csv(output_csv_file, index=False)

# %%
# # Remove duplicate fatalities for the same 'Crash ID' while keeping the first occurrence
# fatality_duplicates_dropped = data_from_2014.drop_duplicates(subset='Crash ID', keep='first')
# fatality_duplicates_dropped

# %%
# Joining for geojson
# Loading the CSV files from the folder
# Defining the file paths
final_file = Path("output_folder/Leaflet_Output/final_merged_csv.csv")
coordinates_file = Path("resources/au_postcodes.csv")

# Reading the CSV files into Pandas DataFrames
final_data = pd.read_csv(final_file)
coordinates_data = pd.read_csv(coordinates_file)

# Adding another column named city to final data duplicating the lgan column
final_data['city'] = final_data['National LGA Name 2021']

# Columns to keep
coordinates_data_columns = ['city','lat','lng']

# merging the CSVs
merged_geojsondata = pd.merge(final_data, coordinates_data[coordinates_data_columns], on='city', how='inner')

# %%
merged_geojsondata
# Out:
#       Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0     20233054   QLD      9  2023   Saturday  23:00     Single
# 1     20233098   QLD      9  2023     Friday  13:00     Single
# 2     20233067   QLD      9  2023    Tuesday  11:00   Multiple
# 3     20233131   QLD      8  2023   Saturday   2:00   Multiple
# 4     20233171   QLD      8  2023  Wednesday  10:00   Multiple
# ...        ...   ...    ...   ...        ...    ...        ...
# 1914  20145004    WA      4  2014   Thursday   2:10   Multiple
# 1915  20194027    SA     10  2019     Friday   0:10     Single
# 1916  20194028    SA      5  2019   Saturday  17:46     Single
# 1917  20181238   NSW      4  2018     Sunday  15:30     Single
# 1918  20151062   NSW      2  2015   Thursday  12:30     Single
#
#       Number of Fatalities  Speed Limit  National Remoteness Areas  ...  \
# 0                        1           80  Major Cities of Australia  ...
# 1                        1           60  Major Cities of Australia  ...
# 2                        1           70   Inner Regional Australia  ...
# 3                        1           60  Major Cities of Australia  ...
# 4                        1           70  Major Cities of Australia  ...
# ...                    ...          ...                        ...  ...
# 1914                     2           60  Major Cities of Australia  ...
# 1915                     1           50   Outer Regional Australia  ...
# 1916                     1           50   Outer Regional Australia  ...
# 1917                     1          100      Very Remote Australia  ...
# 1918                     1          100      Very Remote Australia  ...
#
#      Easter Period Day of week Time of Day         Road User  Gender Age  \
# 0               No     Weekend       Night            Driver    Male  25
# 1               No     Weekday         Day        Pedestrian    Male  62
# 2               No     Weekday         Day  Motorcycle rider    Male  71
# 3               No     Weekend       Night         Passenger    Male  17
# 4               No     Weekday         Day            Driver  Female  80
# ...            ...         ...         ...               ...     ...  ..
# 1914            No     Weekday       Night         Passenger    Male  20
# 1915            No     Weekday       Night        Pedestrian    Male  51
# 1916            No     Weekend         Day        Pedestrian    Male  20
# 1917            No     Weekend         Day  Motorcycle rider    Male  62
# 1918            No     Weekday         Day  Motorcycle rider    Male  56
#
#         Age Group           city      lat       lng
# 0        17_to_25     Gold Coast -28.0167  153.4000
# 1        40_to_64     Gold Coast -28.0167  153.4000
# 2        65_to_74     Gold Coast -28.0167  153.4000
# 3        17_to_25     Gold Coast -28.0167  153.4000
# 4     75_or_older     Gold Coast -28.0167  153.4000
# ...           ...            ...      ...       ...
# 1914     17_to_25      Fremantle -32.0542  115.7476
# 1915     40_to_64  Mount Gambier -37.8294  140.7828
# 1916     17_to_25  Mount Gambier -37.8294  140.7828
# 1917     40_to_64         Bourke -30.1000  145.9333
# 1918     40_to_64         Bourke -30.1000  145.9333
#
# [1919 rows x 24 columns]

# %%
# changing the column order
new_column_order = [
    'Crash ID', 'State', 'Month', 'Year', 'Dayweek', 'Time', 'Crash Type', 'Number of Fatalities',
    'Speed Limit', 'National Remoteness Areas', 'SA4 Name 2021', 'National LGA Name 2021',
    'city', 'lat', 'lng', 'National Road Type', 'Christmas Period', 'Easter Period',
    'Day of week', 'Time of Day', 'Road User', 'Gender',
    'Age', 'Age Group'
]

# Reorder the columns
merged_geojsondata = merged_geojsondata[new_column_order]
merged_geojsondata
# Out:
#       Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 0     20233054   QLD      9  2023   Saturday  23:00     Single
# 1     20233098   QLD      9  2023     Friday  13:00     Single
# 2     20233067   QLD      9  2023    Tuesday  11:00   Multiple
# 3     20233131   QLD      8  2023   Saturday   2:00   Multiple
# 4     20233171   QLD      8  2023  Wednesday  10:00   Multiple
# ...        ...   ...    ...   ...        ...    ...        ...
# 1914  20145004    WA      4  2014   Thursday   2:10   Multiple
# 1915  20194027    SA     10  2019     Friday   0:10     Single
# 1916  20194028    SA      5  2019   Saturday  17:46     Single
# 1917  20181238   NSW      4  2018     Sunday  15:30     Single
# 1918  20151062   NSW      2  2015   Thursday  12:30     Single
#
#       Number of Fatalities  Speed Limit  National Remoteness Areas  ...  \
# 0                        1           80  Major Cities of Australia  ...
# 1                        1           60  Major Cities of Australia  ...
# 2                        1           70   Inner Regional Australia  ...
# 3                        1           60  Major Cities of Australia  ...
# 4                        1           70  Major Cities of Australia  ...
# ...                    ...          ...                        ...  ...
# 1914                     2           60  Major Cities of Australia  ...
# 1915                     1           50   Outer Regional Australia  ...
# 1916                     1           50   Outer Regional Australia  ...
# 1917                     1          100      Very Remote Australia  ...
# 1918                     1          100      Very Remote Australia  ...
#
#            lng National Road Type Christmas Period  Easter Period  \
# 0     153.4000  Sub-Arterial Road               No             No
# 1     153.4000         Local Road               No             No
# 2     153.4000  Sub-Arterial Road               No             No
# 3     153.4000  Sub-Arterial Road               No             No
# 4     153.4000  Sub-Arterial Road               No             No
# ...        ...                ...              ...            ...
# 1914  115.7476      Arterial Road               No             No
# 1915  140.7828     Collector Road               No             No
# 1916  140.7828         Local Road               No             No
# 1917  145.9333      Arterial Road               No             No
# 1918  145.9333      Arterial Road               No             No
#
#       Day of week Time of Day         Road User  Gender Age    Age Group
# 0         Weekend       Night            Driver    Male  25     17_to_25
# 1         Weekday         Day        Pedestrian    Male  62     40_to_64
# 2         Weekday         Day  Motorcycle rider    Male  71     65_to_74
# 3         Weekend       Night         Passenger    Male  17     17_to_25
# 4         Weekday         Day            Driver  Female  80  75_or_older
# ...           ...         ...               ...     ...  ..          ...
# 1914      Weekday       Night         Passenger    Male  20     17_to_25
# 1915      Weekday       Night        Pedestrian    Male  51     40_to_64
# 1916      Weekend         Day        Pedestrian    Male  20     17_to_25
# 1917      Weekend         Day  Motorcycle rider    Male  62     40_to_64
# 1918      Weekday         Day  Motorcycle rider    Male  56     40_to_64
#
# [1919 rows x 24 columns]

# %%
# Specifying the output folder 
output_folder = "output_folder/Leaflet_Output"

# Creating the output folder 
import os
os.makedirs(output_folder, exist_ok=True)

# Defining the file path for the CSV
output_csv_file = os.path.join(output_folder, "merged_geojsondata.csv")

# Saving the DataFrame as a CSV file
merged_geojsondata.to_csv(output_csv_file, index=False)
